# %%
import numpy as np

# %%
arr = np.array(["julie"])

# %%
arr
# Out:
# array(['julie'], dtype='<U5')

# %%
import pandas as pd

# %%
df = pd.DataFrame(arr)

# %%
df
# Out:
#        0
# 0  julie

# %%
import seaborn as sns

# %%
pip install -U scikit-learn
# Out:
# ...
#                                               0.0/8.3 MB ? eta -:--:--
#                                               0.0/8.3 MB 1.3 MB/s eta 0:00:07
#                                               0.1/8.3 MB 871.5 kB/s eta 0:00:10
#                                               0.1/8.3 MB 871.5 kB/s eta 0:00:10
#                                               0.1/8.3 MB 599.1 kB/s eta 0:00:14
#                                               0.2/8.3 MB 697.2 kB/s eta 0:00:12
#                                               0.2/8.3 MB 697.2 kB/s eta 0:00:12
#      -                                        0.2/8.3 MB 595.3 kB/s eta 0:00:14
#      -                                        0.2/8.3 MB 600.7 kB/s eta 0:00:14
#      -                                        0.3/8.3 MB 630.9 kB/s eta 0:00:13
#      -                                        0.3/8.3 MB 630.9 kB/s eta 0:00:13
#      -                                        0.3/8.3 MB 630.9 kB/s eta 0:00:13
# ...

# %%
df = sns.load_dataset("tips")

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(df, kde = True, bins = 10, discrete = False)

# %%
dtf = sns.load_dataset("titanic")

# %%
dtf.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df["name"] = ["julie","john","joice"]
df["age"] = [22,25,50]
df["job"] = ["myntra", "vip","teacher"]

# %%
df
# Out:
#     name  age      job
# 0  julie   22   myntra
# 1   john   25      vip
# 2  joice   50  teacher

# %%
df["name"].append("lisa")
df["age"].append(27)
df["job"].append("Sap")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63916\146088997.py in ?()
# ----> 1 df["name"].append("lisa")
#       2 df["age"].append(27)
#       3 df["job"].append("Sap")
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
new_df = pd.Series(["lisa",27,"sap"], index =["name", "age","job"])

# %%
new_df
# Out:
# name    lisa
# age       27
# job      sap
# dtype: object

# %%
df.append(new_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63916\2926145030.py in ?()
# ----> 1 df.append(new_df)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
dft = df.set_index(df["age"])

# %%
dft
# Out:
#       name  age      job
# age
# 22   julie   22   myntra
# 25    john   25      vip
# 50   joice   50  teacher

# %%
dft.loc[25]
# Out:
# name    john
# age       25
# job      vip
# Name: 25, dtype: object

# %%
dft.reset_index(drop = True)
# Out:
#     name  age      job
# 0  julie   22   myntra
# 1   john   25      vip
# 2  joice   50  teacher

# %%
import seaborn as sns
df = sns.load_dataset("tips")

# %%
df.head()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mat

# %%
df = sns.load_dataset("titanic")

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
des = df.describe(percentiles = [0.1,0.25,0.50,0.75,0.30], include = "float64", exclude = "object"  )

# %%
des
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 10%     14.000000    7.550000
# 25%     20.125000    7.910400
# 30%     22.000000    8.050000
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
des = df.describe(percentiles = [0.1,0.25,0.50,0.75,0.30], include = ["float64", "category","int64","bool"], exclude = "object"  )

# %%
des
# Out:
#           survived      pclass         age       sibsp       parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.383838    2.308642   29.699118    0.523008    0.381594
# std       0.486592    0.836071   14.526497    1.102743    0.806057
# min       0.000000    1.000000    0.420000    0.000000    0.000000
# 10%       0.000000    1.000000   14.000000    0.000000    0.000000
# 25%       0.000000    2.000000   20.125000    0.000000    0.000000
# 30%       0.000000    2.000000   22.000000    0.000000    0.000000
# 50%       0.000000    3.000000   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   38.000000    1.000000    0.000000
# max       1.000000    3.000000   80.000000    8.000000    6.000000
#
# ...

# %%
des = df.describe(percentiles = [0.1,0.25,0.50,0.75,0.30], include = ["float64", "category","bool"], exclude = ["int64","object"])

# %%
des
# Out:
#                age        fare  class adult_male deck alone
# count   714.000000  891.000000    891        891  203   891
# unique         NaN         NaN      3          2    7     2
# top            NaN         NaN  Third       True    C  True
# freq           NaN         NaN    491        537   59   537
# mean     29.699118   32.204208    NaN        NaN  NaN   NaN
# std      14.526497   49.693429    NaN        NaN  NaN   NaN
# min       0.420000    0.000000    NaN        NaN  NaN   NaN
# 10%      14.000000    7.550000    NaN        NaN  NaN   NaN
# 25%      20.125000    7.910400    NaN        NaN  NaN   NaN
# 30%      22.000000    8.050000    NaN        NaN  NaN   NaN
# 50%      28.000000   14.454200    NaN        NaN  NaN   NaN
# 75%      38.000000   31.000000    NaN        NaN  NaN   NaN
# max      80.000000  512.329200    NaN        NaN  NaN   NaN

# %%
des.shape
# Out:
# (13, 6)

# %%
df.shape
# Out:
# (891, 15)

# %%
df.shape[0]
# Out:
# 891

# %%
df.shape[1]
# Out:
# 15

# %%
des.dtypes
# Out:
# age           float64
# fare          float64
# class          object
# adult_male     object
# deck           object
# alone          object
# dtype: object

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.sample(10, random_state = 42)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 709         1       3    male   NaN      1      1  15.2458        C   Third
# 439         0       2    male  31.0      0      0  10.5000        S  Second
# 840         0       3    male  20.0      0      0   7.9250        S   Third
# 720         1       2  female   6.0      0      1  33.0000        S  Second
# 39          1       3  female  14.0      1      0  11.2417        C   Third
# 290         1       1  female  26.0      0      0  78.8500        S   First
# 300         1       3  female   NaN      0      0   7.7500        Q   Third
# 333         0       3    male  16.0      2      0  18.0000        S   Third
# 208         1       3  female  16.0      0      0   7.7500        Q   Third
# 136         1       1  female  19.0      0      2  26.2833        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 709    man        True  NaN    Cherbourg   yes  False
# ...

# %%
df.sample(n = 10, random_state = 42)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 709         1       3    male   NaN      1      1  15.2458        C   Third
# 439         0       2    male  31.0      0      0  10.5000        S  Second
# 840         0       3    male  20.0      0      0   7.9250        S   Third
# 720         1       2  female   6.0      0      1  33.0000        S  Second
# 39          1       3  female  14.0      1      0  11.2417        C   Third
# 290         1       1  female  26.0      0      0  78.8500        S   First
# 300         1       3  female   NaN      0      0   7.7500        Q   Third
# 333         0       3    male  16.0      2      0  18.0000        S   Third
# 208         1       3  female  16.0      0      0   7.7500        Q   Third
# 136         1       1  female  19.0      0      2  26.2833        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 709    man        True  NaN    Cherbourg   yes  False
# ...

# %%
df.sample(frac = 0.10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 117         0       2    male  29.0      1      0  21.0000        S  Second
# 798         0       3    male  30.0      0      0   7.2292        C   Third
# 52          1       1  female  49.0      1      0  76.7292        C   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 247         1       2  female  24.0      0      2  14.5000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 126         0       3    male   NaN      0      0   7.7500        Q   Third
# 289         1       3  female  22.0      0      0   7.7500        Q   Third
# 613         0       3    male   NaN      0      0   7.7500        Q   Third
# 770         0       3    male  24.0      0      0   9.5000        S   Third
# 141         1       3  female  22.0      0      0   7.7500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
dro = df.nunique(dropna = True)

# %%
dro
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
dro.shape
# Out:
# (15,)

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.loc[:10,"age"]
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: age, dtype: float64

# %%
df.loc[0:20, ["alone","alive","age"]]
# Out:
#     alone alive   age
# 0   False    no  22.0
# 1   False   yes  38.0
# 2    True   yes  26.0
# 3   False   yes  35.0
# 4    True    no  35.0
# 5    True    no   NaN
# 6    True    no  54.0
# 7   False    no   2.0
# 8   False   yes  27.0
# 9   False   yes  14.0
# 10  False   yes   4.0
# 11   True   yes  58.0
# 12   True    no  20.0
# 13  False    no  39.0
# 14   True    no  14.0
# 15   True   yes  55.0
# 16  False    no   2.0
# 17   True   yes   NaN
# 18  False    no  31.0
# 19   True   yes   NaN
# 20   True    no  35.0

# %%
df.loc[:, "survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
df.iloc[0:10,:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1
# 4         0       3    male  35.0      0
# 5         0       3    male   NaN      0
# 6         0       1    male  54.0      0
# 7         0       3    male   2.0      3
# 8         1       3  female  27.0      0
# 9         1       2  female  14.0      1

# %%
fil = df["deck"].fillna(method = "ffill")

# %%
fil
# Out:
# 0      NaN
# 1        C
# 2        C
# 3        C
# 4        C
#       ...
# 886      C
# 887      B
# 888      B
# 889      C
# 890      C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
fil.nunique()
# Out:
# 7

# %%
fil.isnull().sum()
# Out:
# 1

# %%
fil = df["deck"].fillna(method = "bfill")d

# %%
fil
# Out:
# 0        C
# 1        C
# 2        C
# 3        C
# 4        E
#       ...
# 886      B
# 887      B
# 888      C
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
fil.isnull().sum()
# Out:
# 1

# %%
df["embark_town"].dropna(inplace  = True)

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.value_counts()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 1         1       female  24.0  0      0      69.3000   C         First  woman  False       B     Cherbourg    yes    True     2
#                           58.0  0      0      26.5500   S         First  woman  False       C     Southampton  yes    True     1
#                           49.0  0      0      25.9292   S         First  woman  False       D     Southampton  yes    True     1
#                                 1      0      76.7292   C         First  woman  False       D     Cherbourg    yes    False    1
#                           50.0  0      1      247.5208  C         First  woman  False       B     Cherbourg    yes    False    1
#                                                                                                                               ..
# ...

# %%
df.rename(columns = {"pclass":"class"}, inplace = True)

# %%
df.head()
# Out:
#     survived class     sex   age  sibsp  parch     fare embarked  class  \
# 1          1     1  female  38.0      1      0  71.2833        C  First
# 3          1     1  female  35.0      1      0  53.1000        S  First
# 6          0     1    male  54.0      0      0  51.8625        S  First
# 10         1     3  female   4.0      1      1  16.7000        S  Third
# 11         1     1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
df.rename(columns = {"sex":"gender", "fare":"amount"}, inplace = True)

# %%
df
# Out:
#      survived class  gender   age  sibsp  parch   amount embarked  class  \
# 1           1     1  female  38.0      1      0  71.2833        C  First
# 3           1     1  female  35.0      1      0  53.1000        S  First
# 6           0     1    male  54.0      0      0  51.8625        S  First
# 10          1     3  female   4.0      1      1  16.7000        S  Third
# 11          1     1  female  58.0      0      0  26.5500        S  First
# ..        ...   ...     ...   ...    ...    ...      ...      ...    ...
# 871         1     1  female  47.0      1      1  52.5542        S  First
# 872         0     1    male  33.0      0      0   5.0000        S  First
# 879         1     1  female  56.0      0      1  83.1583        C  First
# 887         1     1  female  19.0      0      0  30.0000        S  First
# 889         1     1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.replace(np.nan, "XXXX").tail(10)
# Out:
#      survived class  gender   age  sibsp  parch   amount embarked  class  \
# 835         1     1  female  39.0      1      1  83.1583        C  First
# 853         1     1  female  16.0      0      1  39.4000        S  First
# 857         1     1    male  51.0      0      0  26.5500        S  First
# 862         1     1  female  48.0      0      0  25.9292        S  First
# 867         0     1    male  31.0      0      0  50.4958        S  First
# 871         1     1  female  47.0      1      1  52.5542        S  First
# 872         0     1    male  33.0      0      0   5.0000        S  First
# 879         1     1  female  56.0      0      1  83.1583        C  First
# 887         1     1  female  19.0      0      0  30.0000        S  First
# 889         1     1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 835  woman       False    E    Cherbourg   yes  False
# 853  woman       False    D  Southampton   yes  False
# ...

# %%
df["embark_town"].isin(["Cherbourg"]).tail(10)
# Out:
# 835     True
# 853    False
# 857    False
# 862    False
# 867    False
# 871    False
# 872    False
# 879     True
# 887    False
# 889     True
# Name: embark_town, dtype: bool

# %%
df.sort_values(by = "deck")
# Out:
#      survived class  gender   age  sibsp  parch   amount embarked   class  \
# 599         1     1    male  49.0      1      0  56.9292        C   First
# 647         1     1    male  56.0      0      0  35.5000        C   First
# 209         1     1    male  40.0      0      0  31.0000        C   First
# 867         0     1    male  31.0      0      0  50.4958        S   First
# 445         1     1    male   4.0      0      2  81.8583        S   First
# ..        ...   ...     ...   ...    ...    ...      ...      ...     ...
# 66          1     2  female  29.0      0      0  10.5000        S  Second
# 205         0     3  female   2.0      0      1  10.4625        S   Third
# 251         0     3  female  29.0      1      1  10.4625        S   Third
# 10          1     3  female   4.0      1      1  16.7000        S   Third
# 394         1     3  female  24.0      0      2  16.7000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ge = df.get(["survived","amount"])

# %%
ge
# Out:
#      survived   amount
# 1           1  71.2833
# 3           1  53.1000
# 6           0  51.8625
# 10          1  16.7000
# 11          1  26.5500
# ..        ...      ...
# 871         1  52.5542
# 872         0   5.0000
# 879         1  83.1583
# 887         1  30.0000
# 889         1  30.0000
#
# [182 rows x 2 columns]

# %%
df.get("age")
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 182, dtype: float64

# %%
df.get("country", default = "no country")
# Out:
# 'no country'

# %%
df["age"].sum()
# Out:
# 6483.42

# %%
df["age"].max()
# Out:
# 80.0

# %%
df["age"].min()
# Out:
# 0.92

# %%
df["age"].std()
# Out:
# 15.671615357379704

# %%
df["age"].var()
# Out:
# 245.59952790965937

# %%
df["age"].prod()
# Out:
# 1.7514390404793494e+269

# %%
df["age"].mean()
# Out:
# 35.62318681318681

# %%
df["age"].mode()
# Out:
# 0    36.0
# Name: age, dtype: float64

# %%
df["age"].count()
# Out:
# 182

# %%
df["age"].first(offset = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35172\4246723417.py in ?()
# ----> 1 df["age"].first(offset = True)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, offset)
#    8952         3 days observed in the dataset, and therefore data for 2018-04-13 was
#    8953         not returned.
#    8954         """
#    8955         if not isinstance(self.index, DatetimeIndex):
# -> 8956             raise TypeError("'first' only supports a DatetimeIndex index")
#    8957
#    8958         if len(self.index) == 0:
#    8959             return self.copy(deep=False)
#
# TypeError: 'first' only supports a DatetimeIndex index

# %%
df["age"].cumsum()
# Out:
# 1        38.00
# 3        73.00
# 6       127.00
# 10      131.00
# 11      189.00
#         ...
# 871    6349.42
# 872    6382.42
# 879    6438.42
# 887    6457.42
# 889    6483.42
# Name: age, Length: 182, dtype: float64

# %%
df["age"].cumprod()
# Out:
# 1       3.800000e+01
# 3       1.330000e+03
# 6       7.182000e+04
# 10      2.872800e+05
# 11      1.666224e+07
#            ...
# 871    1.918519e+263
# 872    6.331113e+264
# 879    3.545423e+266
# 887    6.736304e+267
# 889    1.751439e+269
# Name: age, Length: 182, dtype: float64
